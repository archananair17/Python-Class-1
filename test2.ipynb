# %% [markdown]
# <a href="https://colab.research.google.com/github/archananair17/Python-Class-1/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("HRDataset_v14.csv")

# %%
df
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0         Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 4            Anderson, Carol   10069.0        0.0              2.0    Male
# ..                        ...      ...        ...              ...     ...
# 307        Ybarra, Catherine   10301.0        0.0              0.0  Female
# 308          Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309               Zhou, Julia  10043.0        0.0              0.0    Male
# 310             Zima, Colleen  10271.0        0.0              4.0    Male
# 311                       NaN      NaN        NaN              NaN    Male
#
# ...

# %%
a=df.loc[df['Position'] == "Production Technician I"]
a.groupby("Position").count()
# Out:
#                          Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# Position
# Production Technician I            137    137        137              137
#
#                          Gender  EmpStatusID  DeptID  PerfScoreID  \
# Position
# Production Technician I     137          137     137          137
#
#                          FromDiversityJobFairID  Salary  ...  \
# Position                                                 ...
# Production Technician I                     137     137  ...
#
#                          PerformanceRating  StandardHours  StockOptionLevel  \
# Position
# Production Technician I                137            137               137
#
#                          TotalWorkingYears  TrainingTimesLastYear  \
# Position
# Production Technician I                137                    137
#
#                          WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Position
# ...

# %%
df.loc[df['Gender'] == "Male"]
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID Gender  \
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0   Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0   Male
# 4            Anderson, Carol   10069.0        0.0              2.0   Male
# 5           Anderson, Linda    10002.0        0.0              0.0   Male
# 7                 Athwal, Sam  10062.0        0.0              4.0   Male
# ..                        ...      ...        ...              ...    ...
# 306            Woodson, Jason  10135.0        0.0              0.0   Male
# 308          Zamora, Jennifer  10010.0        0.0              0.0   Male
# 309               Zhou, Julia  10043.0        0.0              0.0   Male
# 310             Zima, Colleen  10271.0        0.0              4.0   Male
# 311                       NaN      NaN        NaN              NaN   Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[df['ManagerName'] == "Michael Albert"]
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 14            Barton, Nader  10066.0        0.0              2.0    Male
# 23           Blount, Dianna  10294.0        0.0              0.0    Male
# 41         Chace, Beatrice   10067.0        0.0              0.0  Female
# 58        Crimmings,   Jean  10132.0        0.0              0.0    Male
# 83           Erilus, Angela  10299.0        0.0              3.0  Female
# 84        Estremera, Miguel  10280.0        0.0              0.0    Male
# 102         Gentry, Mildred  10159.0        1.0              1.0  Female
# 122     Handschiegl, Joanne  10125.0        1.0              1.0  Female
# 129  Homberger, Adrienne  J  10195.0        1.0              1.0  Female
# 143         Johnson, George  10034.0        1.0              1.0  Female
# 148         Keatts, Kramer   10192.0        0.0              0.0    Male
# ...

# %%
df.loc[df['EmploymentStatus'] == "Active"]
# Out:
#            Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0    Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3           Alagbe,Trina  10088.0        1.0              1.0  Female
# 5      Anderson, Linda    10002.0        0.0              0.0    Male
# 6        Andreola, Colby  10194.0        0.0              0.0  Female
# 7            Athwal, Sam  10062.0        0.0              4.0    Male
# ..                   ...      ...        ...              ...     ...
# 305        Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306       Woodson, Jason  10135.0        0.0              0.0    Male
# 308     Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309          Zhou, Julia  10043.0        0.0              0.0    Male
# 310        Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df['EmploymentStatus'] == "Active")  &  (df['MaritalDesc'] == "Married")]
# Out:
#          Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 3         Alagbe,Trina  10088.0        1.0              1.0  Female
# 16    Beak, Kimberly    10023.0        1.0              1.0    Male
# 22       Billis, Helen  10003.0        1.0              1.0  Female
# 26   Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 29          Brown, Mia  10238.0        1.0              1.0  Female
# ..                 ...      ...        ...              ...     ...
# 271   Sullivan, Kissy   10158.0        1.0              1.0    Male
# 272  Sullivan, Timothy  10117.0        1.0              1.0    Male
# 275       Tannen, Biff  10173.0        1.0              1.0  Female
# 287      Turpin, Jumil  10045.0        1.0              1.0    Male
# 288    Valentin,Jackie  10205.0        1.0              1.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[df['Salary'] <60000]
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# 7              Athwal, Sam  10062.0        0.0              4.0    Male
# 8         Bachiochi, Linda  10114.0        0.0              0.0    Male
# 9       Bacong, Alejandro   10250.0        0.0              2.0    Male
# ..                     ...      ...        ...              ...     ...
# 301          Wilber, Barry  10048.0        1.0              1.0  Female
# 302          Wilkes, Annie  10204.0        0.0              2.0    Male
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 307     Ybarra, Catherine   10301.0        0.0              0.0  Female
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
a=df.loc[df['Position'] == "Production Technician II"]
a.groupby("EngagementSurvey").max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#                             Employee_Name    EmpID  MarriedID  \
# EngagementSurvey
# 2.00                       Blount, Dianna  10294.0        0.0
# 2.40                    Pelletier, Ermine  10297.0        1.0
# 3.00                          Miller, Ned  10300.0        1.0
# 3.02                    Akinkuolie, Sarah  10196.0        1.0
# 3.03               Homberger, Adrienne  J  10195.0        1.0
# 3.11                        Walker, Roger  10190.0        0.0
# 3.19                   Buccheri, Joseph    10184.0        0.0
# 3.25                   Burkett, Benjamin   10181.0        1.0
# 3.40                        Wolk, Hang  T  10174.0        0.0
# ...

# %%
df.groupby("Position").Salary.max()
# Out:
# Position
# Accountant I                     64520.0
# Administrative Assistant         55000.0
# Area Sales Manager               74326.0
# BI Developer                     99020.0
# BI Director                     110929.0
# CIO                             220450.0
# Data Analyst                     93554.0
# Data Analyst                     88527.0
# Data Architect                  150290.0
# Database Administrator          114800.0
# Director of Operations          170500.0
# Director of Sales               180000.0
# Enterprise Architect            103613.0
# IT Director                     178000.0
# IT Manager - DB                 148999.0
# IT Manager - Infra              157000.0
# IT Manager - Support            138888.0
# IT Support                       74679.0
# Network Engineer                 76029.0
# President & CEO                 250000.0
# Principal Data Architect        120000.0
# Production Manager               88976.0
# Production Technician I          64991.0
# ...

# %%
df.loc[df["Salary"] <69020.6848874598]
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0      Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 2        Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3             Alagbe,Trina  10088.0        1.0              1.0  Female
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# ..                     ...      ...        ...              ...     ...
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 305          Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306         Woodson, Jason  10135.0        0.0              0.0    Male
# 307     Ybarra, Catherine   10301.0        0.0              0.0  Female
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
df.loc[(df["Salary"] <69020.6848874598) & (df['EmpSatisfaction'] >3)]
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0      Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3             Alagbe,Trina  10088.0        1.0              1.0  Female
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# 7              Athwal, Sam  10062.0        0.0              4.0    Male
# ..                     ...      ...        ...              ...     ...
# 302          Wilkes, Annie  10204.0        0.0              2.0    Male
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 305          Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306         Woodson, Jason  10135.0        0.0              0.0    Male
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=df["DistanceFromHome"]
y=df["EmpSatisfaction"]
plt.scatter(x,y)
plt.show()

# %%
df.loc[df['StockOptionLevel'] >0].count()
# Out:
# Employee_Name                 171
# EmpID                         171
# MarriedID                     171
# MaritalStatusID               171
# Gender                        172
# EmpStatusID                   171
# DeptID                        171
# PerfScoreID                   171
# FromDiversityJobFairID        171
# Salary                        171
# Termd                         171
# PositionID                    171
# Position                      171
# State                         171
# Zip                           171
# DOB                           171
# Sex                           171
# MaritalDesc                   171
# CitizenDesc                   171
# DateofHire                    171
# DateofTermination              59
# TermReason                    171
# EmploymentStatus              171
# Department                    171
# ManagerName                   171
# ManagerID                     169
# RecruitmentSource             171
# ...

# %%
df.loc[df['PerformanceRating'] >3].count()
# Out:
# Employee_Name                 57
# EmpID                         57
# MarriedID                     57
# MaritalStatusID               57
# Gender                        57
# EmpStatusID                   57
# DeptID                        57
# PerfScoreID                   57
# FromDiversityJobFairID        57
# Salary                        57
# Termd                         57
# PositionID                    57
# Position                      57
# State                         57
# Zip                           57
# DOB                           57
# Sex                           57
# MaritalDesc                   57
# CitizenDesc                   57
# DateofHire                    57
# DateofTermination             16
# TermReason                    57
# EmploymentStatus              57
# Department                    57
# ManagerName                   57
# ManagerID                     53
# RecruitmentSource             57
# PerformanceScore              57
# ...

# %%
df.loc[df['EmpStatusID'] ==5].count()
# Out:
# Employee_Name                 88
# EmpID                         88
# MarriedID                     88
# MaritalStatusID               88
# Gender                        88
# EmpStatusID                   88
# DeptID                        88
# PerfScoreID                   88
# FromDiversityJobFairID        88
# Salary                        88
# Termd                         88
# PositionID                    88
# Position                      88
# State                         88
# Zip                           88
# DOB                           88
# Sex                           88
# MaritalDesc                   88
# CitizenDesc                   88
# DateofHire                    88
# DateofTermination             88
# TermReason                    88
# EmploymentStatus              88
# Department                    88
# ManagerName                   88
# ManagerID                     88
# RecruitmentSource             88
# PerformanceScore              88
# ...

# %%
df.loc[df['Department'] == "IT/IS"].count()
# Out:
# Employee_Name                 50
# EmpID                         50
# MarriedID                     50
# MaritalStatusID               50
# Gender                        50
# EmpStatusID                   50
# DeptID                        50
# PerfScoreID                   50
# FromDiversityJobFairID        50
# Salary                        50
# Termd                         50
# PositionID                    50
# Position                      50
# State                         50
# Zip                           50
# DOB                           50
# Sex                           50
# MaritalDesc                   50
# CitizenDesc                   50
# DateofHire                    50
# DateofTermination             10
# TermReason                    50
# EmploymentStatus              50
# Department                    50
# ManagerName                   50
# ManagerID                     50
# RecruitmentSource             50
# PerformanceScore              50
# ...

# %%
a=df.groupby("Department").count()
b=a["EmpID"].max()
a.loc[a["EmpID"] ==b]
# Out:
#                    Employee_Name  EmpID  MarriedID  MaritalStatusID  Gender  \
# Department
# Production                   209    209        209              209     209
#
#                    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# Department
# Production                 209     209          209                     209
#
#                    Salary  ...  PerformanceRating  StandardHours  \
# Department                 ...
# Production            209  ...                209            209
#
#                    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# Department
# Production                      209                209                    209
#
#                    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Department
# Production                     209             209                 209
#
#                    YearsSinceLastPromotion  YearsWithCurrManager
# Department
# ...

# %%
a=df.groupby("Department").count()
b=a["EmpID"].min()
a.loc[a["EmpID"] ==b]
# Out:
#                   Employee_Name  EmpID  MarriedID  MaritalStatusID  Gender  \
# Department
# Executive Office              1      1          1                1       1
#
#                   EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# Department
# Executive Office            1       1            1                       1
#
#                   Salary  ...  PerformanceRating  StandardHours  \
# Department                ...
# Executive Office       1  ...                  1              1
#
#                   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# Department
# Executive Office                 1                  1                      1
#
#                   WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Department
# Executive Office                1               1                   1
#
#                   YearsSinceLastPromotion  YearsWithCurrManager
# Department
# Executive Office                        1                     1
#
# ...
